# %% [markdown]
# ## Dataset **MNIST** (Modified National Institute of Standards and Technology)
#
# - **Contenu** : Images de chiffres manuscrits (**0 à 9**)
# - **Taille** : **70 000** images au total
#   - <span style="color:cyan;">**Ensemble d'entraînement**</span> : **60 000** images
#          - Ensemble d'entraînement (Train, Calibration, Validation) : 75%
#   - <span style="color:orange;">**Ensemble de test**</span> : **10 000** images
# -  **Format des images** :
#   - Résolution : **28×28 pixels**
#   - Niveaux de gris (**0 = noir, 255 = blanc**)
# - **Labels** : **Chiffres de 0 à 9** (**10 classes**)

# %% [markdown]
# ## **Méthodes Conformal Prediction : SAPS, RAPS, APS**
#
# ### **1. APS (Adaptive Prediction Sets)**
# ### **2. SAPS (Sorted Adaptive Prediction Sets)**
#
# ### **3. RAPS (Regularized Adaptive Prediction Sets)**
# ### **4. MC Dropout**
# ### **5. Deep ENsemble**
#
# ---
#
# ### **Tableau recap**
# | Méthode |  Principe | Avantages |  Limites |
# |---------|------------|-------------|------------|
# | **APS**  | Ajuste dynamiquement les seuils | Adapté aux ensembles de taille variable | Moins efficace si mal calibré |
# | **SAPS** | Trie les scores avant sélection | Sélection plus précise des classes | Plus coûteux en calcul |
# | **RAPS** | Régularisation des ensembles | Meilleure calibration et compacité | Sensible aux paramètres |

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('.')
results_df = pd.read_csv('../src/results/cp_results.csv')

results_df
# Out:
#    Temperature ScoreMethod          Predictor  CoverageRate  AvgSetSize
# 0          0.5         APS  SplitPredictor_CM        0.9044      0.9177
# 1          0.5        RAPS  SplitPredictor_CM        0.9062      0.9170
# 2          0.5        SAPS  SplitPredictor_CM        0.8979      0.9135
# 3          0.5        TOPK  SplitPredictor_CM        0.9013      0.9100
# 4          0.5         KNN  SplitPredictor_CM        0.8970      0.8982

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

temperatures = results_df["Temperature"].unique()
fig, axes = plt.subplots(len(temperatures), 2, figsize=(12, 6 * len(temperatures)))

if len(temperatures) == 1:
    axes = axes.reshape(1, 2)

for i, temp in enumerate(temperatures):
    df_temp = results_df[results_df["Temperature"] == temp]

    heatmap_coverage = df_temp.pivot_table(index="ScoreMethod", columns="Predictor", values="CoverageRate")
    heatmap_avgsetsize = df_temp.pivot_table(index="ScoreMethod", columns="Predictor", values="AvgSetSize")

    sns.heatmap(heatmap_coverage, annot=True, cmap="Blues", ax=axes[i, 0])
    axes[i, 0].set_title(f"Coverage Rate Heatmap ")

    sns.heatmap(heatmap_avgsetsize, annot=True, cmap="Greens", ax=axes[i, 1])
    axes[i, 1].set_title(f"Avg Set Size Heatmap ")

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append('.')
results_df = pd.read_csv('../src/results/cp_results.csv')

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

temperatures = results_df["Temperature"].unique()
fig, axes = plt.subplots(len(temperatures), 2, figsize=(12, 6 * len(temperatures)))

if len(temperatures) == 1:
    axes = axes.reshape(1, 2)

for i, temp in enumerate(temperatures):
    df_temp = results_df[results_df["Temperature"] == temp]

    heatmap_coverage = df_temp.pivot_table(index="ScoreMethod", columns="Predictor", values="CoverageRate")
    heatmap_avgsetsize = df_temp.pivot_table(index="ScoreMethod", columns="Predictor", values="AvgSetSize")

    sns.heatmap(heatmap_coverage, annot=True, cmap="Blues", ax=axes[i, 0])
    axes[i, 0].set_title(f"Coverage Rate Heatmap ")

    sns.heatmap(heatmap_avgsetsize, annot=True, cmap="Greens", ax=axes[i, 1])
    axes[i, 1].set_title(f"Avg Set Size Heatmap ")

plt.tight_layout()
plt.show()
